# %%
import pandas as pd
import numpy as np
import seaborn as sns
from scipy import stats
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/drive/MyDrive/machine/fetal_health.csv')

# %%
df.head()
# Out:
#    baseline value  accelerations  fetal_movement  uterine_contractions  \
# 0           120.0          0.000             0.0                 0.000
# 1           132.0          0.006             0.0                 0.006
# 2           133.0          0.003             0.0                 0.008
# 3           134.0          0.003             0.0                 0.008
# 4           132.0          0.007             0.0                 0.008
#
#    light_decelerations  severe_decelerations  prolongued_decelerations  \
# 0                0.000                   0.0                       0.0
# 1                0.003                   0.0                       0.0
# 2                0.003                   0.0                       0.0
# 3                0.003                   0.0                       0.0
# 4                0.000                   0.0                       0.0
#
#    abnormal_short_term_variability  mean_value_of_short_term_variability  \
# ...

# %%
df.shape
# Out:
# (2126, 22)

# %%
df.dtypes
# Out:
# baseline value                                            float64
# accelerations                                             float64
# fetal_movement                                            float64
# uterine_contractions                                      float64
# light_decelerations                                       float64
# severe_decelerations                                      float64
# prolongued_decelerations                                  float64
# abnormal_short_term_variability                           float64
# mean_value_of_short_term_variability                      float64
# percentage_of_time_with_abnormal_long_term_variability    float64
# mean_value_of_long_term_variability                       float64
# histogram_width                                           float64
# histogram_min                                             float64
# histogram_max                                             float64
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(13)

# %%
df.shape
# Out:
# (2126, 22)

# %%
df.isnull().sum()
# Out:
# baseline value                                            0
# accelerations                                             0
# fetal_movement                                            0
# uterine_contractions                                      0
# light_decelerations                                       0
# severe_decelerations                                      0
# prolongued_decelerations                                  0
# abnormal_short_term_variability                           0
# mean_value_of_short_term_variability                      0
# percentage_of_time_with_abnormal_long_term_variability    0
# mean_value_of_long_term_variability                       0
# histogram_width                                           0
# histogram_min                                             0
# histogram_max                                             0
# histogram_number_of_peaks                                 0
# histogram_number_of_zeroes                                0
# ...

# %%
df.describe()
# Out:
#        baseline value  accelerations  fetal_movement  uterine_contractions  \
# count     2126.000000    2126.000000     2126.000000           2126.000000
# mean       133.303857       0.003178        0.009481              0.004366
# std          9.840844       0.003866        0.046666              0.002946
# min        106.000000       0.000000        0.000000              0.000000
# 25%        126.000000       0.000000        0.000000              0.002000
# 50%        133.000000       0.002000        0.000000              0.004000
# 75%        140.000000       0.006000        0.003000              0.007000
# max        160.000000       0.019000        0.481000              0.015000
#
#        light_decelerations  severe_decelerations  prolongued_decelerations  \
# count          2126.000000           2126.000000               2126.000000
# mean              0.001889              0.000003                  0.000159
# ...

# %%
df.drop_duplicates(keep='first', inplace=True)
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
fetal_health_counts = df['fetal_health'].value_counts()
fetal_health_counts.index = ['Normal (1)', 'Suspect (2)', 'Pathological (3)']

plt.figure(figsize=(6, 4))
bar_plot = sns.barplot(x=fetal_health_counts.index, y=fetal_health_counts.values, palette='Greens')



for i, count in enumerate(fetal_health_counts.values):
    plt.text(i, count + 0.1, str(count), ha='center', va='bottom', fontsize=10)

plt.title('Count of Fetal Health Categories', fontsize=12)
plt.xlabel('\n Fetal Health Category after remove duplicate data', fontsize=10)
plt.ylabel('Count', fontsize=12)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.ylim(0, max(fetal_health_counts.values) + 1)

plt.tight_layout()
plt.show()

print("\n");
print("\n");

plt.figure(figsize=(8, 6))
plt.pie(fetal_health_counts.values, labels=fetal_health_counts.index, autopct='%1.1f%%', startangle=90, colors=sns.color_palette('Greens'))
plt.title('Distribution of Fetal Health Categories ')
plt.show()
# Out:
# /tmp/ipython-input-11-2188917692.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   bar_plot = sns.barplot(x=fetal_health_counts.index, y=fetal_health_counts.values, palette='Greens')

# %%
correlation_matrix = df.corr()

plt.figure(figsize=(22, 18))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", cbar=True)

plt.title('Correlation Matrix', fontsize=14)
plt.xticks(fontsize=10, rotation=90)
plt.yticks(fontsize=10)

plt.tight_layout()
plt.show()

# %%
df.drop(['histogram_median', 'histogram_mode', 'severe_decelerations', 'histogram_number_of_zeroes', 'fetal_movement'], axis = 1, inplace = True)

# %%
df.shape
# Out:
# (2113, 17)

# %%
df.hist(figsize=(20, 25), bins=15, color='lightgreen', edgecolor='black')

plt.suptitle('Histograms for All Columns', fontsize=16)
plt.tight_layout()
plt.subplots_adjust(top=0.95)

plt.show()

# %%
def perform_anova_analysis(df):


#Analysis of Variance (ANOVA) test
    anova_results = {}

    for feature in df.columns[:-1]:
        classes = [
            group[feature].values
            for name, group in df.groupby('fetal_health')
        ]

        f_statistic, p_value = stats.f_oneway(*classes)

        anova_results[feature] = {
            'f_statistic': f_statistic,
            'p_value': p_value
        }

    results_df = pd.DataFrame(anova_results).T
    results_df['significant'] = results_df['p_value'] < 0.05

    results_df = results_df.sort_values('f_statistic', ascending=False)

    return results_df

def plot_anova_results(results_df):
    # Use Seaborn for styling
    plt.figure(figsize=(12, 5))
    sns.barplot(x=results_df.index, y=results_df['f_statistic'], palette='viridis')  # Use a color palette
    plt.xticks(rotation=45, ha='right')
    plt.title('Feature Significance (F-statistic) from ANOVA Test', fontsize=16)
    plt.xlabel('Features', fontsize=14)
    plt.ylabel('F-statistic', fontsize=14)

    # Add significance markers
    for i, significant in enumerate(results_df['significant']):
        color = 'green' if significant else 'red'
        plt.plot(i, results_df['f_statistic'].iloc[i], 'o', color=color, markersize=8)

    plt.tight_layout()
    sns.despine()  # Remove top and right spines for a cleaner look
    plt.grid(axis='y', linestyle='--', alpha=0.7)  # Add a grid
    return plt

# Call the function and assign the result to the 'results' variable
results = perform_anova_analysis(df)

print("\nANOVA Test Results:")
print("\nTop 5 Most Significant Features:")
print(results.head())
print("\nLeast Significant Features:")
print(results.tail())

plot_anova_results(results)
plt.show()

significant_features = results['significant'].sum()
total_features = len(results)
print(f"\nPercentage of statistically significant features: {(significant_features/total_features)*100:.2f}%")
# Out:
# ANOVA Test Results:
#
# Top 5 Most Significant Features:
#                                                     f_statistic  \
# prolongued_decelerations                             507.304309
# abnormal_short_term_variability                      337.703020
# percentage_of_time_with_abnormal_long_term_vari...   335.386156
# histogram_mean                                       298.759569
# accelerations                                        194.618345
#
#                                                           p_value  significant
# prolongued_decelerations                            1.284117e-180         True
# abnormal_short_term_variability                     5.762476e-128         True
# percentage_of_time_with_abnormal_long_term_vari...  3.337805e-127         True
# histogram_mean                                      5.688802e-115         True
# accelerations                                        2.698959e-78         True
#
# Least Significant Features:
# ...

# %%
# !pip install pingouin


# ... (rest of the code for plotting and printing results remains the same) ...
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204.4/204.4 kB 3.7 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from scipy import stats
import matplotlib.pyplot as plt
from pingouin import welch_anova  # Import Welch's ANOVA function


def perform_welchs_anova(df):

    anova_results = {}

    for feature in df.columns[:-1]:  # Iterate through all features except the last one (target variable)
        # Perform Welch's ANOVA using pingouin library
        welch_result = welch_anova(dv=feature, between='fetal_health', data=df)

        # Extract F-statistic and p-value from the result
        f_statistic = welch_result['F'].iloc[0]
        p_value = welch_result['p-unc'].iloc[0]

        anova_results[feature] = {
            'f_statistic': f_statistic,
            'p_value': p_value
        }

    results_df = pd.DataFrame(anova_results).T  # Create a DataFrame from the results dictionary
    results_df['significant'] = results_df['p_value'] < 0.05  # Mark significant features

    results_df = results_df.sort_values('f_statistic', ascending=False)  # Sort by F-statistic

    return results_df

# %%
# Check if 'histogram_max' is in the DataFrame before dropping
if 'histogram_max' in df.columns:
    df.drop(columns=['histogram_max'], axis=1, inplace=True)
else:
    print("Column 'histogram_max' not found in DataFrame. Skipping drop operation.")

# %%
df
# Out:
#       baseline value  accelerations  uterine_contractions  \
# 0              120.0          0.000                 0.000
# 1              132.0          0.006                 0.006
# 2              133.0          0.003                 0.008
# 3              134.0          0.003                 0.008
# 4              132.0          0.007                 0.008
# ...              ...            ...                   ...
# 2121           140.0          0.000                 0.007
# 2122           140.0          0.001                 0.007
# 2123           140.0          0.001                 0.007
# 2124           140.0          0.001                 0.006
# 2125           142.0          0.002                 0.008
#
#       light_decelerations  prolongued_decelerations  \
# 0                   0.000                       0.0
# 1                   0.003                       0.0
# 2                   0.003                       0.0
# 3                   0.003                       0.0
# ...

# %%
from imblearn.over_sampling import SMOTE  #Synthetic Minority Over-sampling Technique.

X = df.iloc[:, :-1]
Y = df['fetal_health']

smote = SMOTE(sampling_strategy='auto')  # auto means all classes will be resampled to the same number
X_resampled, y_resampled = smote.fit_resample(X, Y)

# %%
X_resampled.shape, y_resampled.value_counts()
# Out:
# ((4938, 15),
#  fetal_health
#  2.0    1646
#  1.0    1646
#  3.0    1646
#  Name: count, dtype: int64)

# %%
import matplotlib.pyplot as plt

# Get the class labels and their counts
class_labels = y_resampled.value_counts().index
class_counts = y_resampled.value_counts().values

# Create the pie chart
plt.figure(figsize=(5, 5))  # Adjust figure size as needed
plt.pie(class_counts, labels=class_labels, autopct='%1.1f%%', startangle=90, colors=['lightgreen', 'lightcoral', 'lightskyblue'])  # Adjust colors as needed
plt.title('Distribution of Class Labels after applying SMOTE')
plt.show()

# %%
from imblearn.under_sampling import EditedNearestNeighbours

X = df.iloc[:, :-1]
Y = df['fetal_health']

enn = EditedNearestNeighbours(sampling_strategy='auto')  # auto means all classes will be resampled to the same number
X_resampled, y_resampled = enn.fit_resample(X, Y)

# %%
X_resampled.shape, y_resampled.value_counts()
# Out:
# ((1741, 15),
#  fetal_health
#  1.0    1459
#  3.0     175
#  2.0     107
#  Name: count, dtype: int64)

# %%
import matplotlib.pyplot as plt

# Get the class labels and their counts
class_labels = y_resampled.value_counts().index
class_counts = y_resampled.value_counts().values

# Create the pie chart
plt.figure(figsize=(6, 6))  # Adjust figure size as needed
plt.pie(class_counts, labels=class_labels, autopct='%1.1f%%', startangle=90, colors=['lightgreen', 'lightcoral', 'lightskyblue'])  # Adjust colors as needed
plt.title('Distribution of Class Labels before SMOTE')
plt.show()

# %%
from imblearn.under_sampling import EditedNearestNeighbours
import pandas as pd # Assuming df is a pandas DataFrame

# Assuming df is already loaded and contains 'fetal_health' as the target column

X = df.iloc[:, :-1]  # Features (all columns except the last one)
Y = df['fetal_health'] # Target variable

# Initialize EditedNearestNeighbours
# 'auto' removes samples from the majority class whose label is not the same as the label of the majority of its neighbors
enn = EditedNearestNeighbours(sampling_strategy='auto', n_neighbors=3) # Added n_neighbors for clarity (default is 3)

# Apply ENN to the dataset
X_resampled_enn, y_resampled_enn = enn.fit_resample(X, Y)

# Print the shape and class distribution after ENN
print("Shape after ENN:", X_resampled_enn.shape)
print("\nClass distribution after ENN:\n", y_resampled_enn.value_counts())

# Note: EditedNearestNeighbours performs undersampling on the majority class(es)
# It does NOT necessarily make all classes have the same number of samples.
# It removes noisy/borderline majority class samples.
# Out:
# Shape after ENN: (1741, 15)
#
# Class distribution after ENN:
#  fetal_health
# 1.0    1459
# 3.0     175
# 2.0     107
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.3, random_state=42)

# %%
X_train.shape, X_test.shape
# Out:
# ((1218, 15), (523, 15))

# %%
import matplotlib.pyplot as plt

# Get the number of samples in each set
train_size = X_train.shape[0]
test_size = X_test.shape[0]

# Define the labels and sizes for the bar chart
labels = ['Training Data', 'Testing Data']
sizes = [train_size, test_size]

# Create the bar chart
plt.figure(figsize=(6, 4))
plt.bar(labels, sizes, color=['purple', 'xkcd:dusty rose'])
plt.ylabel('Number of Samples')
plt.title('Distribution of Training and Testing Data Samples')

# Add the exact counts on top of the bars
for i, size in enumerate(sizes):
    plt.text(i, size + 10, str(size), ha='center')

plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
y_train = y_train.astype(int)
y_test = y_test.astype(int)
# Adjust the target values so they start from 0
y_train = y_train - 1  # Uncomment this line
y_test = y_test - 1

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier # Import RandomForestClassifier


# Define the parameter grid
param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5, 10]
}

# Create the GridSearchCV object
grid_search = GridSearchCV(RandomForestClassifier(), param_grid, cv=5, scoring='accuracy')

# Fit the model to the data
grid_search.fit(X_train_scaled, y_train)

# Get the best parameters and best score
print("Best Parameters:", grid_search.best_params_)
print("Best Score:", grid_search.best_score_)
# Out:
# Best Parameters: {'max_depth': 20, 'min_samples_split': 5, 'n_estimators': 200}
# Best Score: 0.9819469742967011

# %%
# !pip install catboost tensorflow

import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score, roc_auc_score
from sklearn.preprocessing import LabelBinarizer
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier, ExtraTreesClassifier, BaggingClassifier
from catboost import CatBoostClassifier
import xgboost as xgb
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
import lightgbm as lgb
import tensorflow as tf  # Import TensorFlow

# ... (your existing code) ...

models = {
    'DecisionTree': DecisionTreeClassifier(),
    'RandomForest': RandomForestClassifier(),
    'CatBoost': CatBoostClassifier(iterations=100, learning_rate=0.1, depth=6, verbose=0),
    'XGBoost': xgb.XGBClassifier(eval_metric='mlogloss', use_label_encoder=False),
    'SVM': SVC(kernel='linear', probability=True),
    'KNN': KNeighborsClassifier(n_neighbors=5),
    'LogisticRegression': LogisticRegression(max_iter=200),
    'NaiveBayes': GaussianNB(),
    'AdaBoost': AdaBoostClassifier(),
    'GradientBoosting': GradientBoostingClassifier(),
    'LightGBM': lgb.LGBMClassifier(),
   'CNN': tf.keras.models.Sequential([
    tf.keras.layers.Dense(2048, activation='relu', input_shape=(X_train_scaled.shape[1],)),
    tf.keras.layers.Dense(1024, activation='relu'),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dropout(0.4),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dropout(0.1),
    tf.keras.layers.Dense(3, activation='softmax')
]),

}

def train_models(X_train, y_train, X_test, y_test):
    results = {}

    for model_name, model in models.items():
        if model_name == 'CNN':
            # Compile the CNN model
            model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

            # Train the CNN model
            model.fit(X_train, y_train, epochs=10, batch_size=32, verbose=0)  # Adjust epochs and batch_size

            # Get predictions
            y_pred_proba = model.predict(X_test)
            y_pred = y_pred_proba.argmax(axis=1)
        else:
            # Fit the model to the data
            model.fit(X_train, y_train)
            y_pred = model.predict(X_test)
            y_pred_proba = model.predict_proba(X_test)


        accuracy = accuracy_score(y_test, y_pred)

        # Calculate ROC AUC
        lb = LabelBinarizer()
        lb.fit(y_train)
        y_test_bin = lb.transform(y_test)
        roc_auc = roc_auc_score(y_test_bin, y_pred_proba, multi_class='ovr')

        results[model_name] = {
            "accuracy": accuracy,
            "roc_auc": roc_auc
        }

        print(f"\n{model_name} - Accuracy: {accuracy:.4f}, ROC AUC: {roc_auc:.4f}\n")

        cm = confusion_matrix(y_test, y_pred)

        # Plot Confusion Matrix
        plt.figure(figsize=(4, 4))
        sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=[1, 2, 3], yticklabels=[1, 2, 3])
        plt.title(f"Confusion Matrix - {model_name}")
        plt.xlabel('Predicted Labels')
        plt.ylabel('True Labels')
        plt.show()

        # Classification Report
        print(f"\nClassification Report for {model_name}:\n")
        print(classification_report(y_test, y_pred))
        print("\n")

    return results

# Example usage:
results = train_models(X_train_scaled, y_train, X_test_scaled, y_test)

# Print the results for each model
print("Model performance:")
for model_name, metrics in results.items():
    print(f"{model_name}: Accuracy = {metrics['accuracy']:.4f}, ROC AUC = {metrics['roc_auc']:.4f}")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.2/99.2 MB 5.9 MB/s eta 0:00:00
# ...
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# DecisionTree - Accuracy: 0.9790, ROC AUC: 0.9568
# Classification Report for DecisionTree:
#
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       438
#            1       0.97      0.91      0.94        32
#            2       0.92      0.92      0.92        53
#
#     accuracy                           0.98       523
#    macro avg       0.96      0.94      0.95       523
# weighted avg       0.98      0.98      0.98       523
#
#
#
#
# RandomForest - Accuracy: 0.9885, ROC AUC: 0.9993
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming you have the 'results' dictionary containing the accuracy and ROC AUC for each model
# Example: results = {'DecisionTree': {'accuracy': 0.85, 'roc_auc': 0.92}, ...}

model_names = list(results.keys())
accuracies = [results[model]['accuracy'] for model in model_names]
roc_aucs = [results[model]['roc_auc'] for model in model_names]

# Create the bar plot
bar_width = 0.35
index = np.arange(len(model_names))

fig, ax = plt.subplots(figsize=(12, 6))

rects1 = ax.bar(index, accuracies, bar_width, label='Accuracy', color='lightgreen')
rects2 = ax.bar(index + bar_width, roc_aucs, bar_width, label='ROC AUC', color='lightcoral')

# Add labels, title, and legend
ax.set_xlabel('Models')
ax.set_ylabel('Scores')
ax.set_title('Model Performance Comparison')
ax.set_xticks(index + bar_width / 2)
ax.set_xticklabels(model_names, rotation=45, ha='right')
ax.legend()

# Add value labels on top of bars
def add_labels(rects):
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width() / 2, height, f'{height:.2f}', ha='center', va='bottom')

add_labels(rects1)
add_labels(rects2)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.metrics import classification_report

# Assuming you have the trained models in a dictionary called 'models'
# and the test data (X_test_scaled, y_test)

# Create a list to store data for the DataFrame
data = []

for model_name, model in models.items():
    # Get predictions for the current model
    if model_name == 'CNN':
        y_pred_proba = model.predict(X_test_scaled)
        y_pred = y_pred_proba.argmax(axis=1)  # Get class labels from probabilities
    else:
        y_pred = model.predict(X_test_scaled)

    # Generate classification report for the current model
    report = classification_report(y_test, y_pred, output_dict=True)

    # Extract metrics for each class (0, 1, 2)
    for class_label in ['0', '1', '2']:
        precision = report[class_label]['precision']
        recall = report[class_label]['recall']
        f1_score = report[class_label]['f1-score']
        support = report[class_label]['support']

        data.append([model_name, class_label, precision, recall, f1_score, support])

# Create a Pandas DataFrame
df = pd.DataFrame(data, columns=['Model', 'Class', 'Precision', 'Recall', 'F1-Score', 'Support'])

# Print the DataFrame
print(df)

# Optional: Plotting F1-Score for each class and model
import seaborn as sns

plt.figure(figsize=(10, 5))  # Adjust figure size as needed
sns.barplot(x='Model', y='F1-Score', hue='Class', data=df)
plt.xticks(rotation=45, ha='right')
plt.title('F1-Score Comparison for Each Class')
plt.tight_layout()
plt.show()

plt.figure(figsize=(10, 5))  # Adjust figure size as needed
sns.barplot(x='Model', y='Precision', hue='Class', data=df) # Changed 'precision' to 'Precision'
plt.xticks(rotation=45, ha='right')
plt.title('precision Comparison for Each Class')
plt.tight_layout()
plt.show()

plt.figure(figsize=(10, 5))  # Adjust figure size as needed
sns.barplot(x='Model', y='Recall', hue='Class', data=df) # Changed 'precision' to 'Precision'
plt.xticks(rotation=45, ha='right')
plt.title('Recall Comparison for Each Class')
plt.tight_layout()
plt.show()

plt.figure(figsize=(10, 5))  # Adjust figure size as needed
sns.barplot(x='Model', y='Support', hue='Class', data=df) # Changed 'precision' to 'Precision'
plt.xticks(rotation=45, ha='right')
plt.title('Support Comparison for Each Class')
plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
#                  Model Class  Precision    Recall  F1-Score  Support
# 0         DecisionTree     0   0.986364  0.990868  0.988610    438.0
# 1         DecisionTree     1   0.966667  0.906250  0.935484     32.0
# 2         DecisionTree     2   0.924528  0.924528  0.924528     53.0
# 3         RandomForest     0   0.988688  0.997717  0.993182    438.0
# 4         RandomForest     1   1.000000  0.875000  0.933333     32.0
# 5         RandomForest     2   0.981132  0.981132  0.981132     53.0
# 6             CatBoost     0   0.984199  0.995434  0.989784    438.0
# 7             CatBoost     1   0.965517  0.875000  0.918033     32.0
# 8             CatBoost     2   0.980392  0.943396  0.961538     53.0
# ...
